# %%
import numpy as np
import matplotlib as plt
import pymysql
from datetime import datetime, timedelta
from sshtunnel import SSHTunnelForwarder
import pandas as pd
% matplotlib inline
import seaborn as sns

# %% [markdown]
# ## 8/2

# %%
# vips 공시 database에서 유가증권, 코스피 공시 데이터만 select >> dataframe으로 return
with SSHTunnelForwarder(
         ('1.212.234.245', 486),
         ssh_password="vips",
         ssh_username="vips",
         remote_bind_address=('127.0.0.1', 3306)) as server:

    conn = pymysql.connect(host='localhost',
                           port=server.local_bind_port,
                           user='root',
                           passwd='qlqtmajrwk',
                           db='dg',
                           charset='utf8')

    curs = conn.cursor(pymysql.cursors.DictCursor)
    
    sql = "select * from dg.searchDB where (crp_cls = 'K' or crp_cls = 'Y')"
    curs.execute(sql)
    rcp_table = curs.fetchall()

server.stop()

# %%
with SSHTunnelForwarder(
         ('1.212.234.245', 486),
         ssh_password="vips",
         ssh_username="vips",
         remote_bind_address=('127.0.0.1', 3306)) as server:

    conn = pymysql.connect(host='localhost',
                           port=server.local_bind_port,
                           user='root',
                           passwd='qlqtmajrwk',
                           db='dg',
                           charset='utf8')

    curs = conn.cursor(pymysql.cursors.DictCursor)
    
    sql2 = "select * from dg.stockDB"
    curs.execute(sql2)
    stock_table = curs.fetchall()
    conn.commit()
    conn.close()
    
    
server.stop()

# %%
# 0812 13:07 기준 1297983개 공시
len(rcp_table)
# Out:
# 1297983

# %%
# convert from list of dict  to dataframe
rcp_df = pd.DataFrame.from_dict(rcp_table)

# %%
rcp_df['rcp_dt'] = pd.to_datetime(rcp_df['rcp_dt'])
rcp_df['rcp_year'] = rcp_df['rcp_dt'].dt.year
rcp_df['rcp_month'] = rcp_df['rcp_dt'].dt.month
rcp_df['rcp_day'] = rcp_df['rcp_dt'].dt.day

# %%
rcp_df['rcp_dayofweek'] = rcp_df['rcp_dt'].dt.dayofweek
# The day of the week with Monday=0, Sunday=6

# %%
rcp_df.tail()
# Out:
#          crp_cd crp_cls     crp_nm     flr_nm     rcp_dt          rcp_no  \
# 1297978  080420       K      모다이노칩      모다이노칩 2018-08-02  20180802900089
# 1297979  072770       K  네오디안테크놀로지  네오디안테크놀로지 2018-08-02  20180802900119
# 1297980  080160       K       모두투어       모두투어 2018-08-02  20180802900120
# 1297981  072770       K  네오디안테크놀로지  네오디안테크놀로지 2018-08-02  20180802900122
# 1297982  043590       K     크로바하이텍     크로바하이텍 2018-08-02  20180802900130
#
#         rcp_rt rmk rpt_cat                  rpt_nm  rcp_year  rcp_month  \
# 1297978  10:05   코    None  연결재무제표기준영업(잠정)실적(공정공시)      2018          8
# 1297979  10:45   코    None                주주총회소집결의      2018          8
# 1297980  10:44   코    None             기업설명회(IR)개최      2018          8
# 1297981  10:48   코    None        주식명의개서정지(주주명부폐쇄)      2018          8
# 1297982  11:29   코    None            유상증자1차발행가액결정      2018          8
#
#          rcp_day  rcp_dayofweek
# 1297978        2              3
# 1297979        2              3
# 1297980        2              3
# 1297981        2              3
# 1297982        2              3

# %%
rcp_df.groupby('rcp_day')['rcp_no'].count()
# Out:
# rcp_day
# 1     31749
# 2     41887
# 3     37127
# 4     38264
# 5     35365
# 6     36216
# 7     40725
# 8     43111
# 9     42213
# 10    50875
# 11    38990
# 12    42138
# 13    47742
# 14    68622
# 15    53263
# 16    46661
# 17    35189
# 18    34623
# 19    33849
# 20    36395
# 21    36344
# 22    37300
# 23    37213
# 24    37979
# 25    37535
# 26    40323
# 27    45300
# 28    48797
# 29    48078
# 30    54580
# 31    39517
# Name: rcp_no, dtype: int64

# %%
rcp_df.groupby('rcp_dayofweek')['rcp_no'].count()
# Out:
# rcp_dayofweek
# 0    242979
# 1    236425
# 2    224200
# 3    256788
# 4    318061
# 5     19530
# Name: rcp_no, dtype: int64

# %%
rcp_df.groupby('rcp_year')['rcp_no'].count()
# Out:
# rcp_year
# 1999      1102
# 2000     20387
# 2001     32075
# 2002     45489
# 2003     61364
# 2004     63287
# 2005     64288
# 2006     61674
# 2007     68520
# 2008     70355
# 2009     79657
# 2010     74374
# 2011     77785
# 2012     75321
# 2013     80175
# 2014     84694
# 2015     91806
# 2016     92725
# 2017    100678
# 2018     52227
# Name: rcp_no, dtype: int64

# %% [markdown]
# ## rcp_dt를 언제부터 쌓고 있는지 확인

# %%
rcp_df[lambda x : x.rcp_year == 2007] #68520
# Out:
#         crp_cd crp_cls    crp_nm    flr_nm     rcp_dt          rcp_no rcp_rt  \
# 335053  011780       Y    금호석유화학    금호석유화학 2007-06-05  20060918800050   None
# 345297  034120       Y       SBS       SBS 2007-02-09  20061201800222   None
# 345811  000680       Y    LS네트웍스    LS네트웍스 2007-01-09  20061206800176   None
# 346428  008040       Y     사조동아원     사조동아원 2007-01-09  20061211800103   None
# 346656  002380       Y      케이씨씨      케이씨씨 2007-01-08  20061212800243   None
# 346869  005930       Y      삼성전자      삼성전자 2007-01-15  20061213800072   None
# 347190  003570       Y    S&T중공업    S&T중공업 2007-03-13  20061214800331   None
# 348130  002380       Y      케이씨씨      케이씨씨 2007-02-23  20061219800062   None
# 348271  007610       Y      선도전기      선도전기 2007-02-16  20061220800013   None
# 348480  006740       Y      영풍제지      영풍제지 2007-01-02  20061221800014   None
# 348957  000270       Y     기아자동차     기아자동차 2007-01-02  20061226800078   None
# 348959  000270       Y     기아자동차     기아자동차 2007-01-02  20061226800084   None
# 348963  015540       Y     메디플란트     메디플란트 2007-01-04  20061226800128   None
# 348972  000640       Y  동아쏘시오홀딩스  동아쏘시오홀딩스 2007-01-02  20061226800192   None
# 349151  017800       Y   현대엘리베이터   현대엘리베이터 2007-01-03  20061227800049   None
# 349153  002360       Y   SH에너지화학   SH에너지화학 2007-01-03  20061227800057   None
# 349156  004200       Y      고려개발      고려개발 2007-01-02  20061227800063   None
# 349157  034220       Y   LG디스플레이   LG디스플레이 2007-01-05  20061227800065   None
# 349173  006120       Y   SK디스커버리   SK디스커버리 2007-01-03  20061227800152   None
# 349181  003960       Y      사조대림      사조대림 2007-01-11  20061227800207   None
# 349395  002140       Y      고려산업      고려산업 2007-01-02  20061228800035   None
# 349397  001550       Y        조비        조비 2007-01-02  20061228800040   None
# 349398  086280       Y    현대글로비스    현대글로비스 2007-01-03  20061228800044   None
# 349405  016880       Y        웅진        웅진 2007-01-03  20061228800072   None
# 346869   유    G_01                     최대주주등소유주식변동신고서      2007          1
# 347190   유     B_7                        단일판매ㆍ공급계약체결      2007          3
# 348130   유    None                           정기주주총회결과      2007          2
# 348271   유    None                           주주총회소집결의      2007          2
# 348480   유    B_23                       금전대여결정(자율공시)      2007          1
# 348957   유     E_4                   영업실적등에대한전망(공정공시)      2007          1
# 348959   유     E_4                     영업(잠정)실적(공정공시)      2007          1
# 348963   유    None                       기타안내사항(안내공시)      2007          1
# 348972   유     E_4                   영업실적등에대한전망(공정공시)      2007          1
# 349151   유     E_4                   영업실적등에대한전망(공정공시)      2007          1
# 349153   유    G_01                     최대주주등소유주식변동신고서      2007          1
# 349156   유    G_01                     최대주주등소유주식변동신고서      2007          1
# 349157   유    None                  기업설명회(IR)개최(안내공시)      2007          1
# 349173   유    G_01                     최대주주등소유주식변동신고서      2007          1
# 349181   유    None               대표이사(대표집행임원)변경(안내공시)      2007          1
# 349395   유    G_01                     최대주주등소유주식변동신고서      2007          1
# 349397   유    G_01                     최대주주등소유주식변동신고서      2007          1
# 349398   유    None                       기타안내사항(안내공시)      2007          1
# 349405   유     E_4                   영업실적등에대한전망(공정공시)      2007          1
# 349406   유    G_02            최대주주등소유주식변동신고서(최대주주변경시)      2007          1
# 349408  유정    B_22  [첨부추가]매출액또는손익구조30%(대규모법인은15%)이상변경      2007          1
# 349412   유     E_4                     영업(잠정)실적(공정공시)      2007          1
# 349413   유     E_4                     결산실적공시예고(안내공시)      2007          1
# 349416   유    None                           주주총회소집결의      2007          2
# 349419   유    None                  기업설명회(IR)개최(안내공시)      2007          1
# ...     ..     ...                                ...       ...        ...
# 418195   유     B_9                  단일판매ㆍ공급계약체결(자율공시)      2007         12
# 418199   유    C_03                          횡령ㆍ배임혐의발생      2007         12
# 418203   유     E_4                     영업(잠정)실적(공정공시)      2007         12
# 418204   유    G_01                     최대주주등소유주식변동신고서      2007         12
# 418205   유   H2_01                         지주회사의자회사편입      2007         12
# 418207   유    G_01                     최대주주등소유주식변동신고서      2007         12
# 418208   유    G_01                     최대주주등소유주식변동신고서      2007         12
# 418209   유    G_01                     최대주주등소유주식변동신고서      2007         12
# 418211  유정    B_10                     [기재정정]유형자산처분결정      2007         12
# 418219   유    None                       기타안내사항(안내공시)      2007         12
# 418221   유     E_4                     영업(잠정)실적(공정공시)      2007         12
# 418222   유     B_7                        단일판매ㆍ공급계약체결      2007         12
# 418224   유    None                 [첨부정정]기타안내사항(안내공시)      2007         12
# 418225   유    C_03                          횡령ㆍ배임혐의발생      2007         12
# 418226  유정   ET_01                       기타경영사항(자율공시)      2007         12
# 418230   코    None                   수시공시의무관련사항(공정공시)      2007         12
# 418231   코    G_04                             대표이사변경      2007         12
# 418232   코    None                   주식명의개서정지(주주명부폐쇄)      2007         12
# 418233   코    N_05                    조회공시(현저한시황변동관련)      2007         12
# 418234   코    N_05                    조회공시(현저한시황변동관련)      2007         12
# 418235   코    G_04                             대표이사변경      2007         12
# 418236   코    None                       신주인수권행사가액의조정      2007         12
# 418237   코    N_05                    조회공시(현저한시황변동관련)      2007         12
# 418238   코    None                       신주인수권행사가액의조정      2007         12
# 418239  코정     B_7                  [기재정정]단일판매ㆍ공급계약체결      2007         12
# 418240   코    None                           임시주주총회결과      2007         12
# 418241   코     B_9            [기재정정]단일판매ㆍ공급계약체결(자율공시)      2007         12
# 418242   코    None                               추가상장      2007         12
# 418243   코    G_04                             대표이사변경      2007         12
# 418244   코    None                            전환가액의조정      2007         12
#
#         rcp_day  rcp_dayofweek
# 335053        5              1
# 345297        9              4
# 345811        9              1
# 346428        9              1
# 346656        8              0
# 346869       15              0
# 347190       13              1
# 348130       23              4
# 348271       16              4
# 348480        2              1
# 348957        2              1
# 348959        2              1
# 348963        4              3
# 348972        2              1
# 349151        3              2
# 349153        3              2
# 349156        2              1
# 349157        5              4
# 349173        3              2
# 349181       11              3
# 349395        2              1
# 349397        2              1
# 349398        3              2
# 349405        3              2
# 349406       16              1
# 349408       17              2
# 349412       24              2
# 349413       12              4
# 349416       26              0
# 349419       19              4
# ...         ...            ...
# 418195       31              0
# 418199       31              0
# 418203       31              0
# 418204       31              0
# 418205       31              0
# 418207       31              0
# 418208       31              0
# 418209       31              0
# 418211       31              0
# 418219       31              0
# 418221       31              0
# 418222       31              0
# 418224       31              0
# 418225       31              0
# 418226       31              0
# 418230       31              0
# 418231       31              0
# 418232       31              0
# 418233       31              0
# 418234       31              0
# 418235       31              0
# 418236       31              0
# 418237       31              0
# 418238       31              0
# 418239       31              0
# 418240       31              0
# 418241       31              0
# 418242       31              0
# 418243       31              0
# 418244       31              0
#
# [68520 rows x 14 columns]

# %%
rcp_df[rcp_df['rcp_rt'].isnull()]
# Out:
#          crp_cd crp_cls     crp_nm     flr_nm     rcp_dt          rcp_no  \
# 0        023150       Y      MH에탄올      MH에탄올 1999-03-25  19990325000001
# 1        001140       Y         국보         국보 1999-03-25  19990325000003
# 2        014160       Y       대영포장       대영포장 1999-03-25  19990325000008
# 3        002310       Y      아세아제지      아세아제지 1999-03-25  19990325000015
# 4        015360       Y        예스코        예스코 1999-03-25  19990325000016
# 5        003580       Y         동원         동원 1999-03-26  19990326000007
# 6        005030       Y       부산주공       부산주공 1999-03-27  19990327000001
# 7        014910       Y       성문전자       성문전자 1999-03-27  19990327000005
# 8        029530       Y       신도리코       신도리코 1999-03-29  19990329000001
# 9        005320       Y         국동         국동 1999-03-29  19990329000003
# 10       011150       Y      CJ씨푸드      CJ씨푸드 1999-03-29  19990329000007
# 11       017960       Y       한국카본       한국카본 1999-03-29  19990329000013
# 12       004980       Y       성신양회       성신양회 1999-03-29  19990329000032
# 13       015350       Y     부산도시가스     부산도시가스 1999-03-29  19990329000036
# 14       009160       Y     SIMPAC     SIMPAC 1999-03-29  19990329000043
# 15       007340       Y   디티알오토모티브   디티알오토모티브 1999-03-29  19990329000044
# 16       011000       Y     진원생명과학     진원생명과학 1999-03-29  19990329000047
# 17       002350       Y      넥센타이어      넥센타이어 1999-03-29  19990329000048
# 18       000490       Y       대동공업       대동공업 1999-03-29  19990329000051
# 19       005430       Y       한국공항       한국공항 1999-03-29  19990329000052
# 20       002410       Y       범양건영       범양건영 1999-03-29  19990329000053
# 19990329000076 0               1       1         1          1        1
# ...                          ...     ...       ...        ...      ...
# 20180802000021 0               0       1         1          1        1
# 20180802000025 0               0       1         1          1        1
# 20180802000027 0               0       1         1          1        1
# 20180802000029 0               0       1         1          1        1
# 20180802000033 0               0       1         1          1        1
# 20180802000035 0               0       1         1          1        1
# 20180802000040 0               0       1         1          1        1
# 20180802000041 0               0       1         1          1        1
# 20180802000043 0               0       1         1          1        1
# 20180802000045 0               0       1         1          1        1
# 20180802000047 0               0       1         1          1        1
# 20180802000050 0               0       1         1          1        1
# 20180802000060 0               0       1         1          1        1
# 20180802000067 0               0       1         1          1        1
# 20180802000068 0               0       1         1          1        1
# 20180802000069 0               0       1         1          1        1
# 20180802000073 0               0       1         1          1        1
# 20180802000074 0               0       1         1          1        1
# 20180802000078 0               0       1         1          1        1
# 20180802800107 0               0       1         1          1        1
# 20180802800111 0               0       1         1          1        1
# 20180802800123 0               0       1         1          1        1
# 20180802900003 0               0       1         1          1        1
# 20180802900054 0               0       1         1          1        1
# 20180802900088 0               0       1         1          1        1
# 20180802900089 0               0       1         1          1        1
# 20180802900119 0               0       1         1          1        1
# 20180802900120 0               0       1         1          1        1
# 20180802900122 0               0       1         1          1        1
# 20180802900130 0               0       1         1          1        1
#
#                          rcp_dayofweek
# rcp_no         rcp_hour
# 19990325000001 0                     1
# 19990325000003 0                     1
# 19990325000008 0                     1
# 19990325000015 0                     1
# 19990325000016 0                     1
# 19990326000007 0                     1
# 19990327000001 0                     1
# 19990327000005 0                     1
# 19990329000001 0                     1
# 19990329000003 0                     1
# 19990329000007 0                     1
# 19990329000013 0                     1
# 19990329000032 0                     1
# 19990329000036 0                     1
# 19990329000043 0                     1
# 19990329000044 0                     1
# 19990329000047 0                     1
# 19990329000048 0                     1
# 19990329000051 0                     1
# 19990329000052 0                     1
# 19990329000053 0                     1
# 19990329000054 0                     1
# 19990329000057 0                     1
# 19990329000059 0                     1
# 19990329000062 0                     1
# 19990329000070 0                     1
# 19990329000073 0                     1
# 19990329000074 0                     1
# 19990329000075 0                     1
# 19990329000076 0                     1
# ...                                ...
# 20180802000021 0                     1
# 20180802000025 0                     1
# 20180802000027 0                     1
# 20180802000029 0                     1
# 20180802000033 0                     1
# 20180802000035 0                     1
# 20180802000040 0                     1
# 20180802000041 0                     1
# 20180802000043 0                     1
# 20180802000045 0                     1
# 20180802000047 0                     1
# 20180802000050 0                     1
# 20180802000060 0                     1
# 20180802000067 0                     1
# 20180802000068 0                     1
# 20180802000069 0                     1
# 20180802000073 0                     1
# 20180802000074 0                     1
# 20180802000078 0                     1
# 20180802800107 0                     1
# 20180802800111 0                     1
# 20180802800123 0                     1
# 20180802900003 0                     1
# 20180802900054 0                     1
# 20180802900088 0                     1
# 20180802900089 0                     1
# 20180802900119 0                     1
# 20180802900120 0                     1
# 20180802900122 0                     1
# 20180802900130 0                     1
#
# [1297983 rows x 13 columns]

# %% [markdown]
# ## rcp_df에 datecd 만들기

# %%
rcp_df['rcp_year'] = rcp_df['rcp_year'].astype(str)
rcp_df['rcp_month'] = rcp_df['rcp_month'].astype(str)
rcp_df['rcp_day'] = rcp_df['rcp_day'].astype(str)
rcp_df['crp_cd'] = rcp_df['crp_cd'].astype(str)

# %%
rcp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1297983 entries, 0 to 1297982
# Data columns (total 14 columns):
# crp_cd           1297983 non-null object
# crp_cls          1297983 non-null object
# crp_nm           1297983 non-null object
# flr_nm           1297983 non-null object
# rcp_dt           1297983 non-null datetime64[ns]
# rcp_no           1297983 non-null object
# rcp_rt           42272 non-null object
# rmk              1297983 non-null object
# rpt_cat          808899 non-null object
# rpt_nm           1297983 non-null object
# rcp_year         1297983 non-null object
# rcp_month        1297983 non-null object
# rcp_day          1297983 non-null object
# rcp_dayofweek    1297983 non-null int64
# dtypes: datetime64[ns](1), int64(1), object(12)
# memory usage: 138.6+ MB

# %%
rcp_df['rcp_month'] = rcp_df['rcp_month'].str.zfill(2)
rcp_df['rcp_day'] = rcp_df['rcp_day'].str.zfill(2)

# %%
rcp_df['datecd'] = rcp_df.loc[:,'rcp_year'] + rcp_df.loc[:,'rcp_month']\
+ rcp_df.loc[:,'rcp_day'] + rcp_df.loc[:,'crp_cd']

# %%
print(rcp_df.iloc[1255956])
print(rcp_df.iloc[1255957]) #1255957 부터 시간 있음 2018-02-12 13:43
# Out:
# crp_cd                        095190
# crp_cls                            K
# crp_nm                         이엠코리아
# flr_nm                         이엠코리아
# rcp_dt           2018-02-12 00:00:00
# rcp_no                20180212900276
# rcp_rt                          None
# rmk                                코
# rpt_cat                          B_9
# rpt_nm             단일판매ㆍ공급계약체결(자율공시)
# rcp_year                        2018
# rcp_month                          2
# rcp_day                           12
# rcp_dayofweek                      0
# Name: 1255956, dtype: object
# crp_cd                        086670
# crp_cls                            K
# crp_nm                           비엠티
# flr_nm                           비엠티
# rcp_dt           2018-02-12 00:00:00
# rcp_no                20180212900282
# rcp_rt                         13:43
# rmk                                코
# rpt_cat                          E_4
# rpt_nm                영업(잠정)실적(공정공시)
# rcp_year                        2018
# rcp_month                          2
# rcp_day                           12
# rcp_dayofweek                      0
# Name: 1255957, dtype: object

# %% [markdown]
# ## stock_df 와 join (key = datecd)

# %%
rcp_df.tail()
# Out:
#          crp_cd crp_cls     crp_nm     flr_nm     rcp_dt          rcp_no  \
# 1297978  080420       K      모다이노칩      모다이노칩 2018-08-02  20180802900089
# 1297979  072770       K  네오디안테크놀로지  네오디안테크놀로지 2018-08-02  20180802900119
# 1297980  080160       K       모두투어       모두투어 2018-08-02  20180802900120
# 1297981  072770       K  네오디안테크놀로지  네오디안테크놀로지 2018-08-02  20180802900122
# 1297982  043590       K     크로바하이텍     크로바하이텍 2018-08-02  20180802900130
#
#         rcp_rt rmk rpt_cat                  rpt_nm rcp_year rcp_month rcp_day  \
# 1297978  10:05   코    None  연결재무제표기준영업(잠정)실적(공정공시)     2018        08      02
# 1297979  10:45   코    None                주주총회소집결의     2018        08      02
# 1297980  10:44   코    None             기업설명회(IR)개최     2018        08      02
# 1297981  10:48   코    None        주식명의개서정지(주주명부폐쇄)     2018        08      02
# 1297982  11:29   코    None            유상증자1차발행가액결정     2018        08      02
#
#          rcp_dayofweek          datecd
# 1297978              3  20180802080420
# 1297979              3  20180802072770
# 1297980              3  20180802080160
# 1297981              3  20180802072770
# 1297982              3  20180802043590

# %%
# convert from list of dict  to dataframe
stock_df = pd.DataFrame.from_dict(stock_table)

# %%
len(stock_table)
# Out:
# 6818450

# %%
stock_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6818450 entries, 0 to 6818449
# Data columns (total 9 columns):
# close     float64
# crp_cd    object
# date      object
# datecd    object
# diff      float64
# high      float64
# low       float64
# open      float64
# volume    float64
# dtypes: float64(6), object(3)
# memory usage: 468.2+ MB

# %%
stock_df['diff'] = stock_df['diff'].astype(int)
stock_df['high'] = stock_df['high'].astype(int)
stock_df['low'] = stock_df['low'].astype(int)
stock_df['open'] = stock_df['open'].astype(int)
stock_df['volume'] = stock_df['volume'].astype(int)

# %%
stock_df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.5/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# /usr/local/lib/python3.5/dist-packages/IPython/lib/pretty.py in pretty(self, obj)
#     393                             if callable(meth):
#     394                                 return meth(obj, self, cycle)
# --> 395             return _default_pprint(obj, self, cycle)
#     396         finally:
#     397             self.end_group()
#
# /usr/local/lib/python3.5/dist-packages/IPython/lib/pretty.py in _default_pprint(obj, p, cycle)
#     508     if _safe_getattr(klass, '__repr__', None) is not object.__repr__:
#     509         # A user-provided repr. Find newlines and replace them with p.break_()
# --> 510         _repr_pprint(obj, p, cycle)
#     511         return
#     512     p.begin_group(1, '<')
#
# /usr/local/lib/python3.5/dist-packages/IPython/lib/pretty.py in _repr_pprint(obj, p, cycle)
#     699     """A pprint that just redirects to the normal repr function."""
#     700     # Find newlines and replace them with p.break_()
# --> 701     output = repr(obj)
#     702     for idx,output_line in enumerate(output.splitlines()):
#     703         if idx:
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/base.py in __repr__(self)
#      78         Yields Bytestring in Py2, Unicode String in py3.
#      79         """
# ---> 80         return str(self)
#      81
#      82
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/base.py in __str__(self)
#      57
#      58         if compat.PY3:
# ---> 59             return self.__unicode__()
#      60         return self.__bytes__()
#      61
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/frame.py in __unicode__(self)
#     634             width = None
#     635         self.to_string(buf=buf, max_rows=max_rows, max_cols=max_cols,
# --> 636                        line_width=width, show_dimensions=show_dimensions)
#     637
#     638         return buf.getvalue()
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/frame.py in to_string(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, line_width, max_rows, max_cols, show_dimensions)
#    1673                                            max_cols=max_cols,
#    1674                                            show_dimensions=show_dimensions)
# -> 1675         formatter.to_string()
#    1676
#    1677         if buf is None:
#
# /usr/local/lib/python3.5/dist-packages/pandas/io/formats/format.py in to_string(self)
#     595         else:
#     596
# --> 597             strcols = self._to_str_columns()
#     598             if self.line_width is None:  # no need to wrap around just print
#     599                 # the whole frame
#
# /usr/local/lib/python3.5/dist-packages/pandas/io/formats/format.py in _to_str_columns(self)
#     530                 header_colwidth = max(self.col_space or 0,
#     531                                       *(self.adj.len(x) for x in cheader))
# --> 532                 fmt_values = self._format_col(i)
#     533                 fmt_values = _make_fixed_width(fmt_values, self.justify,
#     534                                                minimum=header_colwidth,
#
# /usr/local/lib/python3.5/dist-packages/pandas/io/formats/format.py in _format_col(self, i)
#     706         return format_array(values_to_format, formatter,
#     707                             float_format=self.float_format, na_rep=self.na_rep,
# --> 708                             space=self.col_space, decimal=self.decimal)
#     709
#     710     def to_html(self, classes=None, notebook=False, border=None):
#
# /usr/local/lib/python3.5/dist-packages/pandas/io/formats/format.py in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal)
#    1820                         space=space, justify=justify, decimal=decimal)
#    1821
# -> 1822     return fmt_obj.get_result()
#    1823
#    1824
#
# /usr/local/lib/python3.5/dist-packages/pandas/io/formats/format.py in get_result(self)
#    1840
#    1841     def get_result(self):
# -> 1842         fmt_values = self._format_strings()
#    1843         return _make_fixed_width(fmt_values, self.justify)
#    1844
#
# /usr/local/lib/python3.5/dist-packages/pandas/io/formats/format.py in _format_strings(self)
#    2026         # shortcut
#    2027         if self.formatter is not None:
# -> 2028             return [self.formatter(x) for x in self.values]
#    2029
#    2030         return list(self.get_result_as_array())
#
# /usr/local/lib/python3.5/dist-packages/pandas/io/formats/format.py in <listcomp>(.0)
#    2026         # shortcut
#    2027         if self.formatter is not None:
# -> 2028             return [self.formatter(x) for x in self.values]
#    2029
#    2030         return list(self.get_result_as_array())
#
# ValueError: Unknown format code 'd' for object of type 'float'
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.5/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/frame.py in _repr_html_(self)
#     667
#     668             return self.to_html(max_rows=max_rows, max_cols=max_cols,
# --> 669                                 show_dimensions=show_dimensions, notebook=True)
#     670         else:
#     671             return None
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/frame.py in to_html(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, bold_rows, classes, escape, max_rows, max_cols, show_dimensions, notebook, decimal, border)
#    1732                                            decimal=decimal)
#    1733         # TODO: a generic formatter wld b in DataFrameFormatter
# -> 1734         formatter.to_html(classes=classes, notebook=notebook, border=border)
#    1735
#    1736         if buf is None:
#
# /usr/local/lib/python3.5/dist-packages/pandas/io/formats/format.py in to_html(self, classes, notebook, border)
#     731                                       border=border)
#     732         if hasattr(self.buf, 'write'):
# --> 733             html_renderer.write_result(self.buf)
#     734         elif isinstance(self.buf, compat.string_types):
#     735             with open(self.buf, 'w') as f:
#
# /usr/local/lib/python3.5/dist-packages/pandas/io/formats/format.py in write_result(self, buf)
#    1214         indent += self.indent_delta
#    1215         indent = self._write_header(indent)
# -> 1216         indent = self._write_body(indent)
#    1217
#    1218         self.write('</table>', indent)
#
# /usr/local/lib/python3.5/dist-packages/pandas/io/formats/format.py in _write_body(self, indent)
#    1370         fmt_values = {}
#    1371         for i in range(min(len(self.columns), self.max_cols)):
# -> 1372             fmt_values[i] = self.fmt._format_col(i)
#    1373
#    1374         # write values
#
# /usr/local/lib/python3.5/dist-packages/pandas/io/formats/format.py in _format_col(self, i)
#     706         return format_array(values_to_format, formatter,
#     707                             float_format=self.float_format, na_rep=self.na_rep,
# --> 708                             space=self.col_space, decimal=self.decimal)
#     709
#     710     def to_html(self, classes=None, notebook=False, border=None):
#
# /usr/local/lib/python3.5/dist-packages/pandas/io/formats/format.py in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal)
#    1820                         space=space, justify=justify, decimal=decimal)
#    1821
# -> 1822     return fmt_obj.get_result()
#    1823
#    1824
#
# /usr/local/lib/python3.5/dist-packages/pandas/io/formats/format.py in get_result(self)
#    1840
#    1841     def get_result(self):
# -> 1842         fmt_values = self._format_strings()
#    1843         return _make_fixed_width(fmt_values, self.justify)
#    1844
#
# /usr/local/lib/python3.5/dist-packages/pandas/io/formats/format.py in _format_strings(self)
#    2026         # shortcut
#    2027         if self.formatter is not None:
# -> 2028             return [self.formatter(x) for x in self.values]
#    2029
#    2030         return list(self.get_result_as_array())
#
# /usr/local/lib/python3.5/dist-packages/pandas/io/formats/format.py in <listcomp>(.0)
#    2026         # shortcut
#    2027         if self.formatter is not None:
# -> 2028             return [self.formatter(x) for x in self.values]
#    2029
#    2030         return list(self.get_result_as_array())
#
# ValueError: Unknown format code 'd' for object of type 'float'

# %%
stock_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6818450 entries, 0 to 6818449
# Data columns (total 9 columns):
# close     float64
# crp_cd    object
# date      object
# datecd    object
# diff      int64
# high      int64
# low       int64
# open      int64
# volume    int64
# dtypes: float64(1), int64(5), object(3)
# memory usage: 468.2+ MB

# %%
join_df = rcp_df.merge(stock_df, on = 'datecd', how = 'left') #join과 merge의 차이점?

# %%
join_df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.5/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# /usr/local/lib/python3.5/dist-packages/IPython/lib/pretty.py in pretty(self, obj)
#     393                             if callable(meth):
#     394                                 return meth(obj, self, cycle)
# --> 395             return _default_pprint(obj, self, cycle)
#     396         finally:
#     397             self.end_group()
#
# /usr/local/lib/python3.5/dist-packages/IPython/lib/pretty.py in _default_pprint(obj, p, cycle)
#     508     if _safe_getattr(klass, '__repr__', None) is not object.__repr__:
#     509         # A user-provided repr. Find newlines and replace them with p.break_()
# --> 510         _repr_pprint(obj, p, cycle)
#     511         return
#     512     p.begin_group(1, '<')
#
# /usr/local/lib/python3.5/dist-packages/IPython/lib/pretty.py in _repr_pprint(obj, p, cycle)
#     699     """A pprint that just redirects to the normal repr function."""
#     700     # Find newlines and replace them with p.break_()
# --> 701     output = repr(obj)
#     702     for idx,output_line in enumerate(output.splitlines()):
#     703         if idx:
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/base.py in __repr__(self)
#      78         Yields Bytestring in Py2, Unicode String in py3.
#      79         """
# ---> 80         return str(self)
#      81
#      82
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/base.py in __str__(self)
#      57
#      58         if compat.PY3:
# ---> 59             return self.__unicode__()
#      60         return self.__bytes__()
#      61
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/frame.py in __unicode__(self)
#     634             width = None
#     635         self.to_string(buf=buf, max_rows=max_rows, max_cols=max_cols,
# --> 636                        line_width=width, show_dimensions=show_dimensions)
#     637
#     638         return buf.getvalue()
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/frame.py in to_string(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, line_width, max_rows, max_cols, show_dimensions)
#    1673                                            max_cols=max_cols,
#    1674                                            show_dimensions=show_dimensions)
# -> 1675         formatter.to_string()
#    1676
#    1677         if buf is None:
#
# /usr/local/lib/python3.5/dist-packages/pandas/io/formats/format.py in to_string(self)
#     595         else:
#     596
# --> 597             strcols = self._to_str_columns()
#     598             if self.line_width is None:  # no need to wrap around just print
#     599                 # the whole frame
#
# /usr/local/lib/python3.5/dist-packages/pandas/io/formats/format.py in _to_str_columns(self)
#     530                 header_colwidth = max(self.col_space or 0,
#     531                                       *(self.adj.len(x) for x in cheader))
# --> 532                 fmt_values = self._format_col(i)
#     533                 fmt_values = _make_fixed_width(fmt_values, self.justify,
#     534                                                minimum=header_colwidth,
#
# /usr/local/lib/python3.5/dist-packages/pandas/io/formats/format.py in _format_col(self, i)
#     706         return format_array(values_to_format, formatter,
#     707                             float_format=self.float_format, na_rep=self.na_rep,
# --> 708                             space=self.col_space, decimal=self.decimal)
#     709
#     710     def to_html(self, classes=None, notebook=False, border=None):
#
# /usr/local/lib/python3.5/dist-packages/pandas/io/formats/format.py in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal)
#    1820                         space=space, justify=justify, decimal=decimal)
#    1821
# -> 1822     return fmt_obj.get_result()
#    1823
#    1824
#
# /usr/local/lib/python3.5/dist-packages/pandas/io/formats/format.py in get_result(self)
#    1840
#    1841     def get_result(self):
# -> 1842         fmt_values = self._format_strings()
#    1843         return _make_fixed_width(fmt_values, self.justify)
#    1844
#
# /usr/local/lib/python3.5/dist-packages/pandas/io/formats/format.py in _format_strings(self)
#    2026         # shortcut
#    2027         if self.formatter is not None:
# -> 2028             return [self.formatter(x) for x in self.values]
#    2029
#    2030         return list(self.get_result_as_array())
#
# /usr/local/lib/python3.5/dist-packages/pandas/io/formats/format.py in <listcomp>(.0)
#    2026         # shortcut
#    2027         if self.formatter is not None:
# -> 2028             return [self.formatter(x) for x in self.values]
#    2029
#    2030         return list(self.get_result_as_array())
#
# ValueError: Unknown format code 'd' for object of type 'float'
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.5/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/frame.py in _repr_html_(self)
#     667
#     668             return self.to_html(max_rows=max_rows, max_cols=max_cols,
# --> 669                                 show_dimensions=show_dimensions, notebook=True)
#     670         else:
#     671             return None
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/frame.py in to_html(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, bold_rows, classes, escape, max_rows, max_cols, show_dimensions, notebook, decimal, border)
#    1732                                            decimal=decimal)
#    1733         # TODO: a generic formatter wld b in DataFrameFormatter
# -> 1734         formatter.to_html(classes=classes, notebook=notebook, border=border)
#    1735
#    1736         if buf is None:
#
# /usr/local/lib/python3.5/dist-packages/pandas/io/formats/format.py in to_html(self, classes, notebook, border)
#     731                                       border=border)
#     732         if hasattr(self.buf, 'write'):
# --> 733             html_renderer.write_result(self.buf)
#     734         elif isinstance(self.buf, compat.string_types):
#     735             with open(self.buf, 'w') as f:
#
# /usr/local/lib/python3.5/dist-packages/pandas/io/formats/format.py in write_result(self, buf)
#    1214         indent += self.indent_delta
#    1215         indent = self._write_header(indent)
# -> 1216         indent = self._write_body(indent)
#    1217
#    1218         self.write('</table>', indent)
#
# /usr/local/lib/python3.5/dist-packages/pandas/io/formats/format.py in _write_body(self, indent)
#    1370         fmt_values = {}
#    1371         for i in range(min(len(self.columns), self.max_cols)):
# -> 1372             fmt_values[i] = self.fmt._format_col(i)
#    1373
#    1374         # write values
#
# /usr/local/lib/python3.5/dist-packages/pandas/io/formats/format.py in _format_col(self, i)
#     706         return format_array(values_to_format, formatter,
#     707                             float_format=self.float_format, na_rep=self.na_rep,
# --> 708                             space=self.col_space, decimal=self.decimal)
#     709
#     710     def to_html(self, classes=None, notebook=False, border=None):
#
# /usr/local/lib/python3.5/dist-packages/pandas/io/formats/format.py in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal)
#    1820                         space=space, justify=justify, decimal=decimal)
#    1821
# -> 1822     return fmt_obj.get_result()
#    1823
#    1824
#
# /usr/local/lib/python3.5/dist-packages/pandas/io/formats/format.py in get_result(self)
#    1840
#    1841     def get_result(self):
# -> 1842         fmt_values = self._format_strings()
#    1843         return _make_fixed_width(fmt_values, self.justify)
#    1844
#
# /usr/local/lib/python3.5/dist-packages/pandas/io/formats/format.py in _format_strings(self)
#    2026         # shortcut
#    2027         if self.formatter is not None:
# -> 2028             return [self.formatter(x) for x in self.values]
#    2029
#    2030         return list(self.get_result_as_array())
#
# /usr/local/lib/python3.5/dist-packages/pandas/io/formats/format.py in <listcomp>(.0)
#    2026         # shortcut
#    2027         if self.formatter is not None:
# -> 2028             return [self.formatter(x) for x in self.values]
#    2029
#    2030         return list(self.get_result_as_array())
#
# ValueError: Unknown format code 'd' for object of type 'float'

# %% [markdown]
# ## 당일종가 - 당일시가

# %% [markdown]
# ## 당일종가 - 전일종가
