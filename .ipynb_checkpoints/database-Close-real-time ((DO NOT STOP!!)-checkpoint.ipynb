# %%
from datetime import datetime
from time import sleep
import pymysql
import pandas as pd

# %%
# MySQL Connection 연결 (DB 연결)
def setting_db():
    conn = pymysql.connect(host="localhost", 
                       port=3306, user="root", 
                       passwd="qlqtmajrwk",
                       db="yejinyDB",
                       charset="utf8")
    cursor = conn.cursor()# (pymysql.cursors.DictCursor) # 리스트로 받기(tuple은 conn.cursor())
    return conn, cursor

# %%
while True:
    today = datetime.today()
    if today.hour == 16:
        print(today.month, "월", today.day, "일", " Close data 가 기록되었습니다.")
        sleep(3600) #1시간 sleep
    else:
        sleep(3600) #10시간 sleep
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-156fedaa5a0f> in <module>()
#       5         sleep(3600) #1시간 sleep
#       6     else:
# ----> 7         sleep(3600) #10시간 sleep
#
# KeyboardInterrupt:

# %%
# Close Table 만들기
conn, cursor = setting_db()
# 종목코드 crp_cd 법인구분 crp_cls 기업명 crp_nm 업종코드 mrk_cd 업종명 mrk_nm
# 상장주식수 listed(stocks) 자본금 capital 액면가 par(value) 통화 currency 주소 addr
sql = '''CREATE TABLE Close (
                            crp_cd nvarchar(45) NOT NULL,
                            today_dt datetime NOT NULL,
                            open bigint,
                            high bigint,
                            low bigint,
                            close bigint,
                            diff bigint,
                            volume bigint,
                            primary key (crp_cd, today_dt)
                    );
                    '''
cursor.execute(sql)
conn.commit()
conn.close()

# %%
#select crp_cd from Crp table
conn, cursor = setting_db()
sql = "select crp_cd from Corp where crp_cls = 'Y' or crp_cls = 'K';"
cursor.execute(sql)
rows = cursor.fetchall()
conn.commit()
conn.close()

# %%
len(rows)
# Out:
# 2050

# %%
li = []
for i in range(0, len(rows)):
    li.append(rows[i][0])

# %%
len(li)
# Out:
# 2050

# %%
def get_url(code):
    url = 'http://finance.naver.com/item/sise_day.nhn?code={code}'.format(code=code)
    print('요청 URL = {}'.format(url))
    return url

# %%
url = get_url(li[0])
df = pd.DataFrame()
for page in range(1, 11):
    pg_url = '{url}&page={page}'.format(url=url, page=page)
    df = df.append(pd.read_html(pg_url, header=0)[0], ignore_index=True)
df = df.dropna()
df = df.rename(columns= {'날짜': 'today_dt', '종가': 'close', '전일비': 'diff', '시가': 'open', '고가': 'high', '저가': 'low', '거래량': 'volume'})
# Out:
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=000020

# %%
fail = []

# %%
for i in range(i, len(li)):
    url = get_url(li[i])
    df = pd.DataFrame()
    for page in range(1, 11):
        pg_url = '{url}&page={page}'.format(url=url, page=page)
        df = df.append(pd.read_html(pg_url, header=0)[0], ignore_index=True)
    df = df.dropna()
    df = df.rename(columns= {'날짜': 'today_dt', '종가': 'close', '전일비': 'diff', '시가': 'open', '고가': 'high', '저가': 'low', '거래량': 'volume'})
    df['crp_cd'] = li[i]
    try:
        df.to_sql(name='Close', con=engine, if_exists='append')
    except:
        print("위의 요청이 실패함")
        fail.append(li[i])
        continue
# Out:
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=026260
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=026890
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=026910
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=026940
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=026960
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=027040

# %%
fail
# Out:
# ['018250']

# %%
li[i]
# Out:
# '026260'

# %%
http://finance.naver.com/item/sise_day.nhn?code=016790

# %%
df
# Out:
#        today_dt    close    diff     open     high      low     volume  crp_cd
# 1    2018.07.18  24150.0  1800.0  25650.0  26450.0  24100.0   151071.0  016790
# 2    2018.07.17  25950.0   950.0  26650.0  27050.0  25850.0   119713.0  016790
# 3    2018.07.16  26900.0   700.0  27900.0  27900.0  26800.0   120715.0  016790
# 4    2018.07.13  27600.0   200.0  28300.0  28700.0  27250.0   243111.0  016790
# 5    2018.07.12  27400.0  1100.0  28300.0  28950.0  27400.0   241891.0  016790
# 9    2018.07.11  28500.0  1050.0  27300.0  30450.0  26200.0   692967.0  016790
# 10   2018.07.10  27450.0   150.0  28500.0  28750.0  27300.0   161285.0  016790
# 11   2018.07.09  27600.0  2700.0  28500.0  29500.0  26800.0   329965.0  016790
# 12   2018.07.06  30300.0   450.0  31150.0  31550.0  28400.0   665941.0  016790
# 13   2018.07.05  29850.0  1450.0  31750.0  33050.0  29750.0   766990.0  016790
# 16   2018.07.04  31300.0   750.0  31150.0  32600.0  30800.0   712068.0  016790
# ...

# %%
df['crp_cd'] = li[0]

# %%
import pandas as pd
from sqlalchemy import create_engine

# MySQL Connector using pymysql
pymysql.install_as_MySQLdb()
import MySQLdb

engine = create_engine("mysql+mysqldb://root:"+"qlqtmajrwk"+"@localhost/yejinyDB", encoding='utf-8')
conn = engine.connect()

# %%
df.to_sql(name='Close', con=engine, if_exists='append')
