# %% [raw]
# start at July, 6th end at
# - rcp_no
# - crp_cd
# - rpt_nm
# - rpt_link
# - rcp_dt
# - now_st
# - rmk

# %%
import pymysql
import requests
import json
import pandas as pd
from datetime import datetime
from time import sleep
import sys

# %%
# MySQL Connection 연결 (DB 연결)
def setting_db():
    conn = pymysql.connect(host="localhost", 
                       port=3306, user="root", 
                       passwd="qlqtmajrwk",
                       db="yejinyDB",
                       charset="utf8")
    cursor = conn.cursor(pymysql.cursors.DictCursor) # 리스트로 받기(tuple은 conn.cursor())
    return conn, cursor

# %%
# Rcp table 만들기
conn, cursor = setting_db()
# 공시접수번호 rcp_no 종목코드 crp_cd 공시접수일자시각 rcp_dt
# 현재주가 now_st 현재전일비 now_diff 현재거래량 volume 현재거래대금 now_trd
# 공시카테고리 rpt_cat 공시내용 rpt_nm 공시링크 rpt_link 참고사항 rmk
sql = '''CREATE TABLE Rcp (rcp_no nvarchar(45) NOT NULL,
                            crp_cd nvarchar(45) NOT NULL,
                            rcp_dt datetime NOT NULL,
                            now_st bigint,
                            now_diff bigint,
                            now_volume bigint,
                            now_trd bigint,
                            rpt_cat nvarchar(45),
                            rpt_nm text NOT NULL,
                            rpt_link nvarchar(100) NOT NULL,
                            rmk nvarchar(45),                            
                            PRIMARY KEY(rcp_no)
                            );
                            '''
cursor.execute(sql)
conn.commit()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# <ipython-input-3-338ec4f4a619> in <module>()
#      18                             );
#      19                             '''
# ---> 20 cursor.execute(sql)
#      21 conn.commit()
#      22 conn.close()
#
# ~/.local/lib/python3.5/site-packages/pymysql/cursors.py in execute(self, query, args)
#     163         query = self.mogrify(query, args)
#     164
# --> 165         result = self._query(query)
#     166         self._executed = query
#     167         return result
#
# ~/.local/lib/python3.5/site-packages/pymysql/cursors.py in _query(self, q)
#     319         conn = self._get_db()
#     320         self._last_executed = q
# --> 321         conn.query(q)
#     322         self._do_get_result()
#     323         return self.rowcount
#
# ~/.local/lib/python3.5/site-packages/pymysql/connections.py in query(self, sql, unbuffered)
#     858                 sql = sql.encode(self.encoding, 'surrogateescape')
#     859         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 860         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     861         return self._affected_rows
#     862
#
# ~/.local/lib/python3.5/site-packages/pymysql/connections.py in _read_query_result(self, unbuffered)
#    1059         else:
#    1060             result = MySQLResult(self)
# -> 1061             result.read()
#    1062         self._result = result
#    1063         if result.server_status is not None:
#
# ~/.local/lib/python3.5/site-packages/pymysql/connections.py in read(self)
#    1347     def read(self):
#    1348         try:
# -> 1349             first_packet = self.connection._read_packet()
#    1350
#    1351             if first_packet.is_ok_packet():
#
# ~/.local/lib/python3.5/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#    1016
#    1017         packet = packet_type(buff, self.encoding)
# -> 1018         packet.check_error()
#    1019         return packet
#    1020
#
# ~/.local/lib/python3.5/site-packages/pymysql/connections.py in check_error(self)
#     382             errno = self.read_uint16()
#     383             if DEBUG: print("errno =", errno)
# --> 384             err.raise_mysql_exception(self._data)
#     385
#     386     def dump(self):
#
# ~/.local/lib/python3.5/site-packages/pymysql/err.py in raise_mysql_exception(data)
#     105         errval = data[3:].decode('utf-8', 'replace')
#     106     errorclass = error_map.get(errno, InternalError)
# --> 107     raise errorclass(errno, errval)
#
# InternalError: (1050, "Table 'Rcp' already exists")

# %%
def get(crp_cd):
    URL = 'http://polling.finance.naver.com/api/realtime.nhn?query=SERVICE_ITEM:'+crp_cd
    data = {'outer': {'inner': 'value'}}
    res = requests.post(URL, data=json.dumps(data))
    tmp = res.json()['result']['areas'][0]['datas'][0]
    return tmp

# %%
get('000720')
# Out:
# {'aa': 25540031200,
#  'aq': 470789,
#  'bps': 58029.41091,
#  'cd': '000720',
#  'cnsEps': 4629,
#  'cr': 0.0,
#  'cv': 0,
#  'dv': 500.0,
#  'eps': 1810,
#  'hv': 54900,
#  'keps': 1810,
#  'll': 38100,
#  'lv': 53500,
#  'ms': 'OPEN',
#  'mt': '1',
#  'nav': None,
#  'nm': '현대건설',
#  'nv': 54300,
#  'ov': 54600,
#  'pcv': 54300,
#  'rf': '3',
#  'sv': 54300,
#  'tyn': 'N',
#  'ul': 70500}

# %%
def get_now(crp_cd):
    URL = 'http://polling.finance.naver.com/api/realtime.nhn?query=SERVICE_ITEM:'+crp_cd
    data = {'outer': {'inner': 'value'}}
    res = requests.post(URL, data=json.dumps(data))
    tmp = res.json()['result']['areas'][0]['datas'][0]
    result = {'now_st':tmp['nv'], 'now_diff':tmp['nv']-tmp['sv'], 'now_volume':tmp['aq'], 'now_trd':tmp['aa']}
    return result

# %%
get_now('005380')
# Out:
# {'now_diff': 2500,
#  'now_st': 124000,
#  'now_trd': 28495895000,
#  'now_volume': 230613}

# %%
log_list = []

# %%
while True:
    try:
        today = datetime.today().strftime('%Y-%m-%d')
        conn, cursor = setting_db()
        sql = "select rcp_no from Rcp where date(rcp_dt) = '"+today+"'"
        cursor.execute(sql)
        old = cursor.fetchall()
        conn.commit()
        conn.close()

        old_no = []
        for i in old[0:(len(old))]:
            rcp_no = i['rcp_no']
            old_no.append(rcp_no)        

        url_dart_list='http://dart.fss.or.kr/api/search.json?auth=92613a8cac3325e99a4b684b864aee1fd24eb775' #yejin's
        new = requests.get(url_dart_list).json()['list']

        new_no = []
        for i in new[0:(len(new))]:
            rcp_no = i['rcp_no']
            new_no.append(rcp_no)        

        change_no = set(new_no).difference(old_no)
        if change_no:
            print('detect')
            change = []
            for i in change_no:
                for li in new:
                    if li['rcp_no'] == i:
                        if len(li['crp_cd']) == 6: # Y, K, N
                            now_dt = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
                            now_tmp = get_now(li['crp_cd'])
                            change.append((li['rcp_no'], li['crp_cd'], now_dt, now_tmp['now_st'], now_tmp['now_diff'], now_tmp['now_volume'], now_tmp['now_trd'], li['rpt_nm'], 'http://dart.fss.or.kr/dsaf001/main.do?rcpNo='+li['rcp_no'], li['rmk']))
                        else:
                            change.append((li['rcp_no'], li['crp_cd'], now_dt, -1, 0, 0, 0, li['rpt_nm'], 'http://dart.fss.or.kr/dsaf001/main.do?rcpNo='+li['rcp_no'], li['rmk']))

            conn, cursor = setting_db()
            sql = '''insert into Rcp(
                    rcp_no, crp_cd, rcp_dt, now_st, now_diff, now_volume, now_trd, rpt_nm, rpt_link, rmk)
                    values (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)'''
            cursor.executemany(sql, change)
            conn.commit()  
            conn.close()

        else:
            now = datetime.today().time()
            if now.minute % 5 == 0:
                print('nothing changed', now)
            sleep(10)

    except:
        e = sys.exc_info()
        nowtime = datetime.now()
        nowtime = nowtime.strftime('%Y-%m-%d %H:%M:%S')
        log_list.append({'time' : nowtime, 'error' : e})
        log_time = open('logfile/Rcp_log_time.txt', 'w')
        print(log_list, file = log_time)
        log_time.close()
        pass
# Out:
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# nothing changed 14:55:25.822443
# nothing changed 14:55:35.889867
# nothing changed 14:55:45.952453
# nothing changed 14:55:56.008967
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# nothing changed 15:00:08.641901
# nothing changed 15:00:18.713724
# nothing changed 15:00:28.779176
# nothing changed 15:00:38.838684
# nothing changed 15:00:48.905529
# nothing changed 15:00:58.966293
# detect
# detect
# detect
# nothing changed 15:05:01.131903
# nothing changed 15:05:11.214368
# nothing changed 15:05:21.276490
# nothing changed 15:05:31.355065
# nothing changed 15:05:41.421844
# nothing changed 15:05:51.483994
# detect
# nothing changed 15:10:03.223391
# nothing changed 15:10:13.299717
# nothing changed 15:10:23.368338
# nothing changed 15:10:33.440984
# nothing changed 15:10:43.506872
# nothing changed 15:10:53.574128
# detect
# detect
# detect
# detect
# detect
# nothing changed 15:15:06.123518
# nothing changed 15:15:16.198157
# nothing changed 15:15:26.264450
# nothing changed 15:15:36.335295
# nothing changed 15:15:46.400995
# detect
# nothing changed 15:15:56.577819
# detect
# detect
# nothing changed 15:20:08.733349
# nothing changed 15:20:18.793430
# nothing changed 15:20:28.857450
# nothing changed 15:20:38.925960
# nothing changed 15:20:48.992151
# nothing changed 15:20:59.084325
# detect
# detect
# detect
# detect
# nothing changed 15:25:01.242082
# nothing changed 15:25:11.308002
# nothing changed 15:25:21.374403
# nothing changed 15:25:31.429774
# nothing changed 15:25:41.500992
# nothing changed 15:25:51.568444
# detect
# nothing changed 15:30:03.433063
# nothing changed 15:30:13.496673
# nothing changed 15:30:23.564797
# nothing changed 15:30:33.626909
# detect
# nothing changed 15:30:43.794706
# nothing changed 15:30:53.855886
# detect
# detect
# nothing changed 15:35:05.894498
# detect
# nothing changed 15:35:16.183805
# nothing changed 15:35:26.255629
# nothing changed 15:35:36.321409
# nothing changed 15:35:46.390276
# detect
# nothing changed 15:35:56.637257
# detect
# nothing changed 15:40:08.504534
# nothing changed 15:40:18.618837
# nothing changed 15:40:28.687804
# nothing changed 15:40:38.750775
# detect
# nothing changed 15:40:49.053602
# nothing changed 15:40:59.117196
# detect
# detect
# nothing changed 15:45:00.939486
# nothing changed 15:45:11.033443
# nothing changed 15:45:21.100250
# nothing changed 15:45:31.163620
# nothing changed 15:45:41.236957
# nothing changed 15:45:51.382106
# detect
# detect
# detect
# nothing changed 15:50:03.654311
# nothing changed 15:50:13.722447
# nothing changed 15:50:23.785689
# detect
# nothing changed 15:50:33.996358
# nothing changed 15:50:44.054011
# nothing changed 15:50:54.135835
# detect
# detect
# detect
# detect
# detect
# detect
# detect
# nothing changed 15:55:06.704300
# nothing changed 15:55:16.769816
# detect
# nothing changed 15:55:26.973356
# detect
# nothing changed 15:55:37.158309
# nothing changed 15:55:47.238723
# detect
# nothing changed 15:55:57.423787
# detect
# detect
# detect
# detect
# detect
# nothing changed 16:00:09.876572
# detect
# nothing changed 16:00:20.140260
# nothing changed 16:00:30.207075
# detect
# nothing changed 16:00:40.408044
# nothing changed 16:00:50.461185
# detect
# detect
# detect
# detect
# nothing changed 16:05:02.960517
# detect
# nothing changed 16:05:13.186954
# nothing changed 16:05:23.258877
# nothing changed 16:05:33.327657
# nothing changed 16:05:43.391699
# nothing changed 16:05:53.463598
# detect
# detect
# detect

# %%
change = []
for i in new_no:
    for li in new:
        if li['rcp_no'] == i:
            now_dt = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
            if len(li['crp_cd']) == 6: # Y, K, N
                now_tmp = get_now(li['crp_cd'])
                change.append((li['rcp_no'], li['crp_cd'], now_dt, now_tmp['now_st'], now_tmp['now_diff'], now_tmp['now_volume'], now_tmp['now_trd'], li['rpt_nm'], 'http://dart.fss.or.kr/dsaf001/main.do?rcpNo='+li['rcp_no'], li['rmk']))
            else:
                change.append((li['rcp_no'], li['crp_cd'], now_dt, -1, 0, 0, 0, li['rpt_nm'], 'http://dart.fss.or.kr/dsaf001/main.do?rcpNo='+li['rcp_no'], li['rmk']))

print(change)
# Out:
# [('20180712000198', '016360', '2018-07-12 14:18:55', 33150, 250, 145953, 4821579800, '증권발행실적보고서', 'http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20180712000198', ''), ('20180712000197', '00113465', '2018-07-12 14:18:55', -1, 0, 0, 0, '증권발행실적보고서', 'http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20180712000197', ''), ('20180712000195', '00831631', '2018-07-12 14:18:55', -1, 0, 0, 0, '임원의변동', 'http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20180712000195', '공'), ('20180712000194', '006800', '2018-07-12 14:18:55', 8150, -30, 943142, 7701915040, '투자설명서(일괄신고)', 'http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20180712000194', ''), ('20180712000193', '00138321', '2018-07-12 14:18:55', -1, 0, 0, 0, '투자설명서(일괄신고)', 'http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20180712000193', ''), ('20180712000190', '00138321', '2018-07-12 14:18:55', -1, 0, 0, 0, '투자설명서(일괄신고)', 'http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20180712000190', ''), ('20180712000183', '01181524', '2018-07-12 14:18:55', -1, 0, 0, 0, '감사보고서 (2018.03)', 'http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20180712000183', ''), ('20180712000180', '156100', '2018-07-12 14:18:55', 9040, -10, 10446, 94108720, '임원ㆍ주요주주특정증권등소유상황보고서', 'http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20180712000180', ''), ('20180712000177', '00986375', '2018-07-12 14:18:55', -1, 0, 0, 0, '자산유동화관련중요사항발생등신고서(기타)', 'http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20180712000177', ''), ('20180712900244', '053590', '2018-07-12 14:18:55', 1385, 30, 1043484, 1436367555, '타법인주식및출자증권취득결정(자율공시)', 'http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20180712900244', '코')]

# %%
conn, cursor = setting_db()
sql = '''insert into Rcp(
        rcp_no, crp_cd, rcp_dt, now_st, now_diff, now_volume, now_trd, rpt_nm, rpt_link, rmk)
        values (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)'''
cursor.executemany(sql, change)
print('here')
#conn.commit()
# Out:
# here

# %%
conn.commit()

# %%
today = datetime.today().strftime('%Y-%m-%d')
conn, cursor = setting_db()
sql = "select rcp_no from Rcp where date(rcp_dt) = '"+today+"'"
cursor.execute(sql)
old = cursor.fetchall()
conn.commit()
conn.close()

old_no = []
for i in old[0:(len(old))]:
    rcp_no = i['rcp_no']
    old_no.append(rcp_no)        

url_dart_list='http://dart.fss.or.kr/api/search.json?auth=92613a8cac3325e99a4b684b864aee1fd24eb775' #yejin's
new = requests.get(url_dart_list).json()['list']

new_no = []
for i in new[0:(len(new))]:
    rcp_no = i['rcp_no']
    new_no.append(rcp_no)        

change_no = set(new_no).difference(old_no)
if change_no:
    print('detect')
    change = []
    for i in change_no:
        for li in new:
            if li['rcp_no'] == i:
                now_dt = datetime.today()
                if len(li['crp_cd']) == 6: # Y, K, N
                    print('등록')
                    now_tmp = get_now(li['crp_cd'])
                    change.extend([[li['rcp_no'], li['crp_cd'], now_dt, now_tmp['now_st'], now_tmp['now_diff'], now_tmp['now_volume'], now_tmp['now_trd'], '', li['rpt_nm'], 'http://dart.fss.or.kr/dsaf001/main.do?rcpNo='+li['rcp_no'], li['rmk']]])
                else:
                    print('미등록')
                    change.extend([[li['rcp_no'], li['crp_cd'], now_dt, -1, 0, 0, 0, li['rpt_nm'], 'http://dart.fss.or.kr/dsaf001/main.do?rcpNo='+li['rcp_no'], li['rmk']]])
    conn, cursor = setting_db()
    sql = '''insert into Rcp(rcp_no, crp_cd, rcp_dt, now_st, now_diff, now_volume, now_trd, rpt_nm, rpt_link, rmk)
            values (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)'''
    print(change)
    cursor.executemany(sql, change)
    conn.commit()  
    conn.close()

else:
    now = datetime.today().time()
    if now.minute % 5 == 0:
        print('nothing changed', now)
    sleep(30)
